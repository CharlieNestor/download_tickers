# %% [markdown]
# # US Tickers Retrieval

# %% [markdown]
# ## Introduction

# %% [markdown]
# This script provides a powerful tool to access and manipulate stock ticker data from the Nasdaq website via API. It allows users to download, filter, and analyze ticker information efficiently. The primary data source is: https://www.nasdaq.com/market-activity/stocks/screener

# %% [markdown]
# ## Setup and Initial Data Retrieval

# %% [markdown]
# First, we import the necessary modules and initialize our `Tickers` class:

# %%
import tickers as tk
import pandas as pd
import numpy as np

# %% [markdown]
# To download the data, we simply instantiate the `Tickers()` class. The retrieved dataset is stored in the `.data` attribute:

# %%
tickers = tk.Tickers()
print(len(tickers.data))
# Out:
# 5529

# %%
tickers.data.head(10)
# Out:
#    symbol                                               name exchange  \
# 0       A             Agilent Technologies Inc. Common Stock     nyse
# 1      AA                    Alcoa Corporation Common Stock      nyse
# 2    AACG   ATA Creativity Global American Depositary Shares   nasdaq
# 3    AACI            Armada Acquisition Corp. I Common Stock   nasdaq
# 6    AACT  Ares Acquisition Corporation II Class A Ordina...     nyse
# 7    AADI                  Aadi Bioscience Inc. Common Stock   nasdaq
# 8    AAGR     African Agriculture Holdings Inc. Common Stock   nasdaq
# 10    AAL          American Airlines Group Inc. Common Stock   nasdaq
# 11   AAMC               Altisource Asset Management Corp Com     amex
# 12   AAME         Atlantic American Corporation Common Stock   nasdaq
#
#       marketCap                  sector  \
# 0   38503682278             Industrials
# 1    6401302877             Industrials
# 2      20643284             Real Estate
# 3             0                 Finance
# 6             0                 Finance
# 7      37567934             Health Care
# 8       9924161        Consumer Staples
# 10   6967679453  Consumer Discretionary
# 11      6386280                 Finance
# 12     34471511                 Finance
#
#                                             industry lastsale    volume  \
# 0   Biotechnology: Laboratory Analytical Instruments  $131.97   2763388
# 1                                           Aluminum   $35.65   8889375
# 2                            Other Consumer Services  $0.6451     75174
# 3                                       Blank Checks  $11.425     48197
# 6                                       Blank Checks   $10.72     63179
# 7         Biotechnology: Pharmaceutical Preparations    $1.53     79821
# 8                              Farming/Seeds/Milling  $0.1715    309035
# 10                     Air Freight/Delivery Services   $10.62  46279007
# 11                                       Real Estate    $2.50       751
# 12                                    Life Insurance  $1.6898      8745
#
#    ipoyear        country                           url
# 0     1999  United States     /market-activity/stocks/a
# 1     2016  United States    /market-activity/stocks/aa
# 2     2008          China  /market-activity/stocks/aacg
# 3     2021  United States  /market-activity/stocks/aaci
# 6     2023                 /market-activity/stocks/aact
# 7           United States  /market-activity/stocks/aadi
# 8     2021  United States  /market-activity/stocks/aagr
# 10          United States   /market-activity/stocks/aal
# 11          United States  /market-activity/stocks/aamc
# 12          United States  /market-activity/stocks/aame

# %% [markdown]
# Note: The `marketCap` field represents market capitalization in USD Millions.

# %%
tickers.data.describe()
# Out:
#        symbol                     name exchange  marketCap  \
# count    5529                     5529     5529       5529
# unique   5529                     5526        3       5441
# top         A  Berkshire Hathaway Inc.   nasdaq          0
# freq        1                        2     3266         89
#
#                         sector                                    industry  \
# count                     5529                                        5529
# unique                      13                                         150
# top     Consumer Discretionary  Biotechnology: Pharmaceutical Preparations
# freq                      1126                                         555
#
#        lastsale  volume ipoyear        country                        url
# count      5529    5529    5529           5529                       5529
# unique     3890    5504      62             59                       5529
# top       $1.70  830334          United States  /market-activity/stocks/a
# freq          9       2    2319           4171                          1

# %% [markdown]
# ## Core Functionalities: Ticker List

# %% [markdown]
# The primary goal of this script is to generate a curated list of stock tickers for further analysis or downloading. This list is dynamically stored in the `.ticker_list` attribute, which updates as we apply filters to the dataset. Initially, it contains all tickers from the dataset:

# %%
print(len(tickers.tickers_list))
tickers.tickers_list
# Out:
# 5529
# ['A',
#  'AA',
#  'AACG',
#  'AACI',
#  'AACT',
#  'AADI',
#  'AAGR',
#  'AAL',
#  'AAMC',
#  'AAME',
#  'AAN',
#  'AAOI',
#  'AAON',
#  'AAP',
#  'AAPL',
#  'AAT',
#  'AB',
#  'ABAT',
#  'ABBV',
#  'ABCB',
#  'ABCL',
#  'ABEO',
#  'ABEV',
#  'ABG',
#  'ABIO',
#  'ABL',
#  'ABLV',
#  'ABM',
#  'ABNB',
#  'ABOS',
#  'ABR',
#  'ABSI',
#  'ABT',
#  'ABTS',
#  'ABUS',
#  'ABVC',
#  'ABVE',
#  'ABVX',
#  'AC',
#  'ACA',
#  'ACAD',
#  'ACB',
#  'ACCD',
#  'ACCO',
#  'ACDC',
#  'ACEL',
#  'ACET',
#  'ACGL',
#  'ACHC',
#  'ACHL',
#  'ACHR',
#  'ACHV',
#  'ACI',
#  'ACIC',
#  'ACIU',
#  'ACIW',
#  'ACLS',
#  'ACLX',
#  'ACM',
#  'ACMR',
#  'ACN',
#  'ACNB',
#  'ACNT',
#  'ACON',
#  'ACR',
#  'ACRE',
#  'ACRS',
#  'ACRV',
#  'ACST',
#  'ACT',
#  'ACTG',
#  'ACU',
#  'ACVA',
#  'ACXP',
#  'ADAG',
#  'ADAP',
#  'ADBE',
#  'ADC',
#  'ADCT',
#  'ADD',
#  'ADEA',
#  'ADI',
#  'ADIL',
#  'ADM',
#  'ADMA',
#  'ADN',
#  'ADNT',
#  'ADP',
#  'ADPT',
#  'ADRT',
#  'ADSE',
#  'ADSK',
#  'ADT',
#  'ADTN',
#  'ADTX',
#  'ADUS',
#  'ADV',
#  'ADVM',
#  'ADXN',
#  'AE',
#  'AEE',
#  'AEG',
#  'AEHL',
#  'AEHR',
#  'AEI',
#  'AEIS',
#  'AEM',
#  'AEMD',
#  'AENT',
#  'AEO',
#  'AEON',
#  'AEP',
#  'AER',
#  'AERT',
#  'AES',
#  'AESI',
#  'AEVA',
#  'AEYE',
#  'AEZS',
#  'AFAR',
#  'AFBI',
#  'AFCG',
#  'AFG',
#  'AFL',
#  'AFMD',
#  'AFRI',
#  'AFRM',
#  'AFYA',
#  'AG',
#  'AGAE',
#  'AGBA',
#  'AGCO',
#  'AGEN',
#  'AGFY',
#  'AGI',
#  'AGIO',
#  'AGL',
#  'AGM',
#  'AGMH',
#  'AGNC',
#  'AGO',
#  'AGR',
#  'AGRI',
#  'AGRO',
#  'AGS',
#  'AGX',
#  'AGYS',
#  'AHCO',
#  'AHG',
#  'AHH',
#  'AHR',
#  'AHT',
#  'AI',
#  'AIEV',
#  'AIG',
#  'AIHS',
#  'AILE',
#  'AIM',
#  'AIMD',
#  'AIN',
#  'AINC',
#  'AIOT',
#  'AIP',
#  'AIR',
#  'AIRE',
#  'AIRG',
#  'AIRI',
#  'AIRJ',
#  'AIRS',
#  'AIRT',
#  'AISP',
#  'AIT',
#  'AIU',
#  'AIV',
#  'AIXI',
#  'AIZ',
#  'AJG',
#  'AJX',
#  'AKA',
#  'AKAM',
#  'AKAN',
#  'AKBA',
#  'AKR',
#  'AKRO',
#  'AKTS',
#  'AKTX',
#  'AKYA',
#  'AL',
#  'ALAB',
#  'ALAR',
#  'ALB',
#  'ALBT',
#  'ALC',
#  'ALCE',
#  'ALCO',
#  'ALDX',
#  'ALE',
#  'ALEC',
#  'ALEX',
#  'ALFUU',
#  'ALG',
#  'ALGM',
#  'ALGN',
#  'ALGS',
#  'ALGT',
#  'ALHC',
#  'ALIM',
#  'ALIT',
#  'ALK',
#  'ALKS',
#  'ALKT',
#  'ALL',
#  'ALLE',
#  'ALLG',
#  'ALLK',
#  'ALLO',
#  'ALLR',
#  'ALLT',
#  'ALLY',
#  'ALMS',
#  'ALNT',
#  'ALNY',
#  'ALOT',
#  'ALPP',
#  'ALRM',
#  'ALRN',
#  'ALRS',
#  'ALSN',
#  'ALT',
#  'ALTG',
#  'ALTI',
#  'ALTM',
#  'ALTO',
#  'ALTR',
#  'ALTS',
#  'ALUR',
#  'ALV',
#  'ALVO',
#  'ALVR',
#  'ALX',
#  'ALXO',
#  'ALZN',
#  'AM',
#  'AMAL',
#  'AMAT',
#  'AMBA',
#  'AMBC',
#  'AMBI',
#  'AMBO',
#  'AMBP',
#  'AMC',
#  'AMCR',
#  'AMCX',
#  'AMD',
#  'AME',
#  'AMED',
#  'AMG',
#  'AMGN',
#  'AMH',
#  'AMIX',
#  'AMK',
#  'AMKR',
#  'AMLI',
#  'AMLX',
#  'AMN',
#  'AMP',
#  'AMPG',
#  'AMPH',
#  'AMPL',
#  'AMPS',
#  'AMPX',
#  'AMPY',
#  'AMR',
#  'AMRC',
#  'AMRK',
#  'AMRN',
#  'AMRX',
#  'AMS',
#  'AMSC',
#  'AMSF',
#  'AMST',
#  'AMSWA',
#  'AMT',
#  'AMTB',
#  'AMTD',
#  'AMTX',
#  'AMWD',
#  'AMWL',
#  'AMX',
#  'AMZN',
#  'AN',
#  'ANAB',
#  'ANDE',
#  'ANEB',
#  'ANET',
#  'ANF',
#  'ANGH',
#  'ANGI',
#  'ANGO',
#  'ANIK',
#  'ANIP',
#  'ANIX',
#  'ANL',
#  'ANNX',
#  'ANRO',
#  'ANSC',
#  'ANSS',
#  'ANTE',
#  'ANTX',
#  'ANVS',
#  'ANY',
#  'AOMR',
#  'AON',
#  'AORT',
#  'AOS',
#  'AOSL',
#  'AOUT',
#  'AP',
#  'APA',
#  'APAM',
#  'APCX',
#  'APD',
#  'APDN',
#  'APEI',
#  'APG',
#  'APGE',
#  'APH',
#  'API',
#  'APLD',
#  'APLE',
#  'APLM',
#  'APLS',
#  'APLT',
#  'APM',
#  'APO',
#  'APOG',
#  'APP',
#  'APPF',
#  'APPN',
#  'APPS',
#  'APRE',
#  'APT',
#  'APTO',
#  'APTV',
#  'APVO',
#  'APWC',
#  'APYX',
#  'AQB',
#  'AQMS',
#  'AQN',
#  'AQST',
#  'AR',
#  'ARAY',
#  'ARBB',
#  'ARBE',
#  'ARBK',
#  'ARC',
#  'ARCB',
#  'ARCC',
#  'ARCH',
#  'ARCO',
#  'ARCT',
#  'ARDT',
#  'ARDX',
#  'ARE',
#  'AREB',
#  'AREC',
#  'AREN',
#  'ARES',
#  'ARGX',
#  'ARHS',
#  'ARI',
#  'ARIS',
#  'ARKO',
#  'ARKR',
#  'ARL',
#  'ARLO',
#  'ARLP',
#  'ARM',
#  'ARMK',
#  'ARMN',
#  'ARMP',
#  'AROC',
#  'AROW',
#  'ARQ',
#  'ARQQ',
#  'ARQT',
#  'ARR',
#  'ARRY',
#  'ARTL',
#  'ARTNA',
#  'ARTW',
#  'ARVN',
#  'ARW',
#  'ARWR',
#  'ARYD',
#  'AS',
#  'ASA',
#  'ASAI',
#  'ASAN',
#  'ASB',
#  'ASC',
#  'ASGN',
#  'ASH',
#  'ASIX',
#  'ASLE',
#  'ASLN',
#  'ASM',
#  'ASMB',
#  'ASML',
#  'ASND',
#  'ASNS',
#  'ASO',
#  'ASPI',
#  'ASPN',
#  'ASPS',
#  'ASR',
#  'ASRT',
#  'ASRV',
#  'ASST',
#  'ASTC',
#  'ASTE',
#  'ASTH',
#  'ASTI',
#  'ASTL',
#  'ASTR',
#  'ASTS',
#  'ASUR',
#  'ASX',
#  'ASXC',
#  'ASYS',
#  'ATAI',
#  'ATAT',
#  'ATCH',
#  'ATEC',
#  'ATEN',
#  'ATER',
#  'ATEX',
#  'ATGE',
#  'ATGL',
#  'ATHA',
#  'ATHE',
#  'ATHM',
#  'ATI',
#  'ATIF',
#  'ATIP',
#  'ATKR',
#  'ATLC',
#  'ATLO',
#  'ATLX',
#  'ATMU',
#  'ATMV',
#  'ATMVR',
#  'ATNF',
#  'ATNI',
#  'ATNM',
#  'ATO',
#  'ATOM',
#  'ATOS',
#  'ATPC',
#  'ATR',
#  'ATRA',
#  'ATRC',
#  'ATRI',
#  'ATRO',
#  'ATS',
#  'ATSG',
#  'ATUS',
#  'ATXG',
#  'ATXI',
#  'ATXS',
#  'ATYR',
#  'AU',
#  'AUB',
#  'AUBN',
#  'AUDC',
#  'AUGX',
#  'AUID',
#  'AULT',
#  'AUMN',
#  'AUNA',
#  'AUPH',
#  'AUR',
#  'AURA',
#  'AUST',
#  'AUTL',
#  'AUUD',
#  'AVA',
#  'AVAH',
#  'AVAL',
#  'AVAV',
#  'AVB',
#  'AVBP',
#  'AVD',
#  'AVDL',
#  'AVDX',
#  'AVGO',
#  'AVGR',
#  'AVIR',
#  'AVNS',
#  'AVNT',
#  'AVNW',
#  'AVO',
#  'AVPT',
#  'AVT',
#  'AVTE',
#  'AVTR',
#  'AVTX',
#  'AVXL',
#  'AVY',
#  'AWH',
#  'AWI',
#  'AWK',
#  'AWR',
#  'AWRE',
#  'AWX',
#  'AX',
#  'AXDX',
#  'AXGN',
#  'AXIL',
#  'AXL',
#  'AXNX',
#  'AXON',
#  'AXP',
#  'AXR',
#  'AXS',
#  'AXSM',
#  'AXTA',
#  'AXTI',
#  'AY',
#  'AYI',
#  'AYRO',
#  'AYTU',
#  'AZ',
#  'AZEK',
#  'AZN',
#  'AZO',
#  'AZPN',
#  'AZTA',
#  'AZTR',
#  'AZUL',
#  'AZZ',
#  'B',
#  'BA',
#  'BABA',
#  'BAC',
#  'BACK',
#  'BAER',
#  'BAFN',
#  'BAH',
#  'BAK',
#  'BALL',
#  'BALY',
#  'BAM',
#  'BANC',
#  'BAND',
#  'BANF',
#  'BANL',
#  'BANR',
#  'BANX',
#  'BAOS',
#  'BAP',
#  'BARK',
#  'BASE',
#  'BATL',
#  'BATRA',
#  'BATRK',
#  'BAX',
#  'BB',
#  'BBAI',
#  'BBAR',
#  'BBCP',
#  'BBD',
#  'BBDC',
#  'BBDO',
#  'BBGI',
#  'BBIO',
#  'BBLG',
#  'BBSI',
#  'BBU',
#  'BBUC',
#  'BBVA',
#  'BBW',
#  'BBWI',
#  'BBY',
#  'BC',
#  'BCAB',
#  'BCAL',
#  'BCAN',
#  'BCAT',
#  'BCBP',
#  'BCC',
#  'BCDA',
#  'BCE',
#  'BCG',
#  'BCH',
#  'BCLI',
#  'BCML',
#  'BCO',
#  'BCOV',
#  'BCOW',
#  'BCPC',
#  'BCRX',
#  'BCS',
#  'BCSF',
#  'BCTX',
#  'BCX',
#  'BCYC',
#  'BDC',
#  'BDJ',
#  'BDL',
#  'BDN',
#  'BDRX',
#  'BDSX',
#  'BDTX',
#  'BDX',
#  'BE',
#  'BEAM',
#  'BEAT',
#  'BECN',
#  'BEDU',
#  'BEEM',
#  'BEEP',
#  'BEKE',
#  'BELFA',
#  'BELFB',
#  'BEN',
#  'BENF',
#  'BEP',
#  'BEPC',
#  'BERY',
#  'BEST',
#  'BETR',
#  'BFAM',
#  'BFC',
#  'BFH',
#  'BFI',
#  'BFIN',
#  'BFK',
#  'BFLY',
#  'BFRG',
#  'BFRI',
#  'BFS',
#  'BFST',
#  'BFZ',
#  'BG',
#  'BGC',
#  'BGFV',
#  'BGI',
#  'BGLC',
#  'BGNE',
#  'BGR',
#  'BGS',
#  'BGSF',
#  'BGXX',
#  'BGY',
#  'BH',
#  'BHAT',
#  'BHB',
#  'BHC',
#  'BHE',
#  'BHF',
#  'BHIL',
#  'BHLB',
#  'BHP',
#  'BHR',
#  'BHRB',
#  'BHVN',
#  'BIAF',
#  'BIDU',
#  'BIG',
#  'BIGC',
#  'BIGZ',
#  'BIIB',
#  'BILI',
#  'BILL',
#  'BIMI',
#  'BIO',
#  'BIOR',
#  'BIOX',
#  'BIP',
#  'BIPC',
#  'BIRD',
#  'BIRK',
#  'BIT',
#  'BITF',
#  'BIVI',
#  'BJ',
#  'BJDX',
#  'BJRI',
#  'BK',
#  'BKD',
#  'BKE',
#  'BKH',
#  'BKHA',
#  'BKKT',
#  'BKN',
#  'BKNG',
#  'BKR',
#  'BKSY',
#  'BKT',
#  'BKTI',
#  'BKU',
#  'BKYI',
#  'BL',
#  'BLBD',
#  'BLBX',
#  'BLCO',
#  'BLD',
#  'BLDE',
#  'BLDP',
#  'BLDR',
#  'BLE',
#  'BLFS',
#  'BLFY',
#  'BLIN',
#  'BLK',
#  'BLKB',
#  'BLMN',
#  'BLND',
#  'BLNK',
#  'BLRX',
#  'BLTE',
#  'BLUE',
#  'BLW',
#  'BLX',
#  'BLZE',
#  'BMA',
#  'BMBL',
#  'BME',
#  'BMEA',
#  'BMEZ',
#  'BMI',
#  'BMN',
#  'BMO',
#  'BMR',
#  'BMRA',
#  'BMRC',
#  'BMRN',
#  'BMTX',
#  'BMY',
#  'BN',
#  'BNAI',
#  'BNED',
#  'BNGO',
#  'BNL',
#  'BNOX',
#  'BNR',
#  'BNRE',
#  'BNRG',
#  'BNS',
#  'BNTC',
#  'BNTX',
#  'BNY',
#  'BNZI',
#  'BOC',
#  'BODI',
#  'BOE',
#  'BOF',
#  'BOH',
#  'BOKF',
#  'BOLD',
#  'BOLT',
#  'BON',
#  'BOOM',
#  'BOOT',
#  'BORR',
#  'BOSC',
#  'BOTJ',
#  'BOW',
#  'BOWL',
#  'BOX',
#  'BOXL',
#  'BP',
#  'BPMC',
#  'BPOP',
#  'BPRN',
#  'BPT',
#  'BPTH',
#  'BQ',
#  'BR',
#  'BRAG',
#  'BRBR',
#  'BRBS',
#  'BRC',
#  'BRCC',
#  'BRDG',
#  'BREA',
#  'BRFH',
#  'BRFS',
#  'BRID',
#  'BRK/A',
#  'BRK/B',
#  'BRKL',
#  'BRKR',
#  'BRLS',
#  'BRLT',
#  'BRN',
#  'BRNS',
#  'BRO',
#  'BROG',
#  'BROS',
#  'BRSP',
#  'BRT',
#  'BRTX',
#  'BRX',
#  'BRY',
#  'BRZE',
#  'BSAC',
#  'BSBK',
#  'BSBR',
#  'BSET',
#  'BSFC',
#  'BSIG',
#  'BSM',
#  'BSRR',
#  'BST',
#  'BSTZ',
#  'BSVN',
#  'BSX',
#  'BSY',
#  'BTA',
#  'BTAI',
#  'BTBD',
#  'BTBT',
#  'BTCM',
#  'BTCS',
#  'BTCT',
#  'BTCY',
#  'BTDR',
#  'BTE',
#  'BTG',
#  'BTI',
#  'BTM',
#  'BTMD',
#  'BTOG',
#  'BTSG',
#  'BTSGU',
#  'BTT',
#  'BTTR',
#  'BTU',
#  'BTZ',
#  'BUD',
#  'BUI',
#  'BUR',
#  'BURL',
#  'BUSE',
#  'BV',
#  'BVFL',
#  'BVN',
#  'BVS',
#  'BW',
#  'BWA',
#  'BWAY',
#  'BWB',
#  'BWEN',
#  'BWFG',
#  'BWIN',
#  'BWLP',
#  'BWMN',
#  'BWMX',
#  'BWXT',
#  'BX',
#  'BXC',
#  'BXMT',
#  'BXP',
#  'BY',
#  'BYD',
#  'BYFC',
#  'BYM',
#  'BYND',
#  'BYON',
#  'BYRN',
#  'BYSI',
#  'BYU',
#  'BZ',
#  'BZFD',
#  'BZH',
#  'BZUN',
#  'C',
#  'CAAP',
#  'CAAS',
#  'CABA',
#  'CABO',
#  'CAC',
#  'CACC',
#  'CACI',
#  'CACO',
#  'CADE',
#  'CADL',
#  'CAE',
#  'CAG',
#  'CAH',
#  'CAKE',
#  'CAL',
#  'CALB',
#  'CALC',
#  'CALM',
#  'CALT',
#  'CALX',
#  'CAMT',
#  'CAN',
#  'CANF',
#  'CANG',
#  'CAPL',
#  'CAPR',
#  'CAPT',
#  'CAR',
#  'CARA',
#  'CARE',
#  'CARG',
#  'CARM',
#  'CARR',
#  'CARS',
#  'CART',
#  'CARV',
#  'CASH',
#  'CASI',
#  'CASS',
#  'CASY',
#  'CAT',
#  'CATO',
#  'CATX',
#  'CATY',
#  'CAUD',
#  'CAVA',
#  'CB',
#  'CBAN',
#  'CBAT',
#  'CBFV',
#  'CBL',
#  'CBNK',
#  'CBRE',
#  'CBRL',
#  'CBSH',
#  'CBT',
#  'CBU',
#  'CBUS',
#  'CBZ',
#  'CC',
#  'CCAP',
#  'CCB',
#  'CCBG',
#  'CCCC',
#  'CCCS',
#  'CCEL',
#  'CCEP',
#  'CCG',
#  'CCI',
#  'CCIX',
#  'CCJ',
#  'CCK',
#  'CCL',
#  'CCLD',
#  'CCM',
#  'CCNE',
#  'CCO',
#  'CCOI',
#  'CCRD',
#  'CCRN',
#  'CCS',
#  'CCSI',
#  'CCTG',
#  'CCU',
#  'CCZ',
#  'CDAQ',
#  'CDE',
#  'CDIO',
#  'CDLR',
#  'CDLX',
#  'CDMO',
#  'CDNA',
#  'CDNS',
#  'CDP',
#  'CDRE',
#  'CDRO',
#  'CDT',
#  'CDTG',
#  'CDTX',
#  'CDW',
#  'CDXC',
#  'CDXS',
#  'CDZI',
#  'CDZIP',
#  'CE',
#  'CEAD',
#  'CECO',
#  'CEG',
#  'CEI',
#  'CEIX',
#  'CELC',
#  'CELH',
#  'CELU',
#  'CELZ',
#  'CENN',
#  'CENT',
#  'CENTA',
#  'CENX',
#  'CEPU',
#  'CERE',
#  ...]

# %% [markdown]
# ## Data Analysis and Filtering

# %% [markdown]
# The `Tickers` class provides several methods to analyze and filter the data. These methods are also implemented in the Streamlit app for user-friendly interaction.

# %% [markdown]
# ### Top Stocks by Market Capitalization

# %% [markdown]
# To retrieve the top 30 stocks by market capitalization:

# %%
tickers.get_biggest_n_tickers(top_n=30)
tickers.data
# Out:
#      symbol                                               name exchange  \
# 17     AAPL                            Apple Inc. Common Stock   nasdaq
# 4001   MSFT                 Microsoft Corporation Common Stock   nasdaq
# 4348   NVDA                    NVIDIA Corporation Common Stock   nasdaq
# 2641   GOOG                Alphabet Inc. Class C Capital Stock   nasdaq
# 2642  GOOGL                 Alphabet Inc. Class A Common Stock   nasdaq
# 350    AMZN                       Amazon.com Inc. Common Stock   nasdaq
# 3803   META           Meta Platforms Inc. Class A Common Stock   nasdaq
# 959   BRK/A                            Berkshire Hathaway Inc.     nyse
# 960   BRK/B                            Berkshire Hathaway Inc.     nyse
# 6060    TSM    Taiwan Semiconductor Manufacturing Company Ltd.     nyse
# 3576    LLY                 Eli Lilly and Company Common Stock     nyse
# 6058   TSLA                            Tesla Inc. Common Stock   nasdaq
# 593    AVGO                         Broadcom Inc. Common Stock   nasdaq
# 3294    JPM                 JP Morgan Chase & Co. Common Stock     nyse
# 4359    NVO                      Novo Nordisk A/S Common Stock     nyse
# 6503    WMT                          Walmart Inc. Common Stock     nyse
# 6170    UNH  UnitedHealth Group Incorporated Common Stock (DE)     nyse
# 6227      V                                          Visa Inc.     nyse
# 6585    XOM               Exxon Mobil Corporation Common Stock     nyse
# 3698     MA               Mastercard Incorporated Common Stock     nyse
# 4729     PG        Procter & Gamble Company (The) Common Stock     nyse
# 4548   ORCL                    Oracle Corporation Common Stock     nyse
# 3284    JNJ                     Johnson & Johnson Common Stock     nyse
# 1462   COST          Costco Wholesale Corporation Common Stock   nasdaq
# 493    ASML         ASML Holding N.V. New York Registry Shares   nasdaq
# 2781     HD                 Home Depot Inc. (The) Common Stock     nyse
# 646     BAC           Bank of America Corporation Common Stock     nyse
# 3975    MRK            Merck & Company Inc. Common Stock (new)     nyse
# 21     ABBV                           AbbVie Inc. Common Stock     nyse
# 1627    CVX                   Chevron Corporation Common Stock     nyse
#
#           marketCap                  sector  \
# 17    3437594502760              Technology
# 4001  3272964502504              Technology
# 4348  2978613229147              Technology
# 2641  2214800760000              Technology
# 2642  2195893020000              Technology
# 350   1912217787506  Consumer Discretionary
# 3803  1207009794787              Technology
# 959    974924704680
# 960    974792489935
# 6060   891389008210              Technology
# 3576   806799132175             Health Care
# 6058   794843360701  Consumer Discretionary
# 593    747201937945              Technology
# 3294   602992821232                 Finance
# 4359   580045185797             Health Care
# 6503   569643738631  Consumer Discretionary
# 6170   519410113226             Health Care
# 6227   492258806157  Consumer Discretionary
# 6585   468429215681                  Energy
# 3698   417137022288  Consumer Discretionary
# 4729   397541186900  Consumer Discretionary
# 4548   380391355800              Technology
# 3284   374046078622             Health Care
# 1462   372122119095  Consumer Discretionary
# 493    363580683462              Technology
# 2781   363010121211  Consumer Discretionary
# 646    336354126818                 Finance
# 3975   314701183645             Health Care
# 21     302210612040             Health Care
# 1627   299160053075                  Energy
#
#                                             industry    lastsale     volume  \
# 17                            Computer Manufacturing     $224.18   65141874
# 4001         Computer Software: Prepackaged Software     $440.37   20723545
# 4348                                  Semiconductors     $121.09  318738227
# 2641  Computer Software: Programming Data Processing     $179.22   17734003
# 2642  Computer Software: Programming Data Processing     $177.69   25259938
# 350                   Catalog/Specialty Distribution     $183.75   50830521
# 3803  Computer Software: Programming Data Processing     $475.85   18931988
# 959                                                   $662820.00       1987
# 960                                                      $441.82    4514203
# 6060                                  Semiconductors     $171.87   50837262
# 3576      Biotechnology: Pharmaceutical Preparations     $848.90    7590524
# 6058                              Auto Manufacturing     $249.23  110398308
# 593                                   Semiconductors     $160.52   37738522
# 3294                                     Major Banks     $209.98   12376737
# 4359      Biotechnology: Pharmaceutical Preparations     $129.99    9752519
# 6503              Department/Specialty Retail Stores      $70.82   10678578
# 6170                            Medical Specialities     $564.34    6833687
# 6227                               Business Services     $269.15    5532867
# 6585                        Integrated oil Companies     $118.80   13026765
# 3698                               Business Services     $448.72    3339805
# 4729                         Package Goods/Cosmetics     $168.44    5662338
# 4548         Computer Software: Prepackaged Software     $138.03    5258543
# 3284      Biotechnology: Pharmaceutical Preparations     $155.42    9340720
# 1462              Department/Specialty Retail Stores     $839.37    2331187
# 493                  Industrial Machinery/Components     $924.15    2237966
# 2781                      RETAIL: Building Materials     $366.08    2345113
# 646                                      Major Banks      $43.01   48522286
# 3975      Biotechnology: Pharmaceutical Preparations     $124.25    9376167
# 21        Biotechnology: Pharmaceutical Preparations     $171.14    5942009
# 1627                        Integrated oil Companies     $161.97    6498324
#
#      ipoyear        country                            url
# 17      1980  United States   /market-activity/stocks/aapl
# 4001    1986  United States   /market-activity/stocks/msft
# 4348    1999  United States   /market-activity/stocks/nvda
# 2641    2004  United States   /market-activity/stocks/goog
# 2642    2004  United States  /market-activity/stocks/googl
# 350     1997  United States   /market-activity/stocks/amzn
# 3803    2012  United States   /market-activity/stocks/meta
# 959           United States  /market-activity/stocks/brk/a
# 960           United States  /market-activity/stocks/brk/b
# 6060    1997         Taiwan    /market-activity/stocks/tsm
# 3576          United States    /market-activity/stocks/lly
# 6058    2010  United States   /market-activity/stocks/tsla
# 593     2009  United States   /market-activity/stocks/avgo
# 3294          United States    /market-activity/stocks/jpm
# 4359                Denmark    /market-activity/stocks/nvo
# 6503          United States    /market-activity/stocks/wmt
# 6170          United States    /market-activity/stocks/unh
# 6227          United States      /market-activity/stocks/v
# 6585          United States    /market-activity/stocks/xom
# 3698    2006  United States     /market-activity/stocks/ma
# 4729          United States     /market-activity/stocks/pg
# 4548    1986  United States   /market-activity/stocks/orcl
# 3284          United States    /market-activity/stocks/jnj
# 1462          United States   /market-activity/stocks/cost
# 493     1995    Netherlands   /market-activity/stocks/asml
# 2781          United States     /market-activity/stocks/hd
# 646           United States    /market-activity/stocks/bac
# 3975          United States    /market-activity/stocks/mrk
# 21      2012  United States   /market-activity/stocks/abbv
# 1627          United States    /market-activity/stocks/cvx

# %% [markdown]
# Important notes:
# 1. These methods modify the `.data` attribute in-place.
# 2. The `.original_dataset` attribute remains unmodified, serving as a backup of the clean original dataset.

# %%
print(len(tickers.data))
print(len(tickers.original_dataset))
# Out:
# 30
# 5529

# %% [markdown]
# If needed, you can reset the `.data` attribute to its original state using the `.reset_data()` method:

# %%
tickers.reset_data()
print(len(tickers.data))
print(len(tickers.original_dataset))
# Out:
# 5529
# 5529

# %% [markdown]
# ### Applying Filters

# %% [markdown]
# Let's explore various filtering options:

# %%
tickers.apply_filters(exchange='nyse', sectors='Finance')
print(len(tickers.data))
tickers.data
# Out:
# 390
#      symbol                                               name exchange  \
# 6      AACT  Ares Acquisition Corporation II Class A Ordina...     nyse
# 19       AB              AllianceBernstein Holding L.P.  Units     nyse
# 33      ABM           ABM Industries Incorporated Common Stock     nyse
# 45       AC         Associated Capital Group Inc. Common Stock     nyse
# 125     AEG                Aegon Ltd. New York Registry Shares     nyse
# ...     ...                                                ...      ...
# 6518    WRB              W.R. Berkley Corporation Common Stock     nyse
# 6534     WT                       WisdomTree Inc. Common Stock     nyse
# 6540    WTM  White Mountains Insurance Group Ltd. Common Stock     nyse
# 6609    XYF  X Financial American Depositary Shares each re...     nyse
# 6631    YRD  Yiren Digital Ltd. American Depositary Shares ...     nyse
#
#      marketCap   sector                            industry  lastsale  \
# 6          0.0  Finance                        Blank Checks    $10.72
# 19      3869.5  Finance                 Investment Managers    $33.60
# 33     3374.17  Finance     Diversified Commercial Services    $53.76
# 45      703.04  Finance  Investment Bankers/Brokers/Service    $32.85
# 125   13755.99  Finance                      Life Insurance     $6.24
# ...        ...      ...                                 ...       ...
# 6518  21556.15  Finance          Property-Casualty Insurers    $56.21
# 6534   1639.62  Finance  Investment Bankers/Brokers/Service    $10.80
# 6540   4425.48  Finance          Property-Casualty Insurers  $1724.84
# 6609    211.36  Finance          Finance: Consumer Services     $4.32
# 6631    418.16  Finance          Finance: Consumer Services     $4.81
#
#        volume ipoyear         country                           url
# 6       63179    2023                  /market-activity/stocks/aact
# 19     238101           United States    /market-activity/stocks/ab
# 33     466259           United States   /market-activity/stocks/abm
# 45       7103    2015   United States    /market-activity/stocks/ac
# 125   1249160             Netherlands   /market-activity/stocks/aeg
# ...       ...     ...             ...                           ...
# 6518  1158109           United States   /market-activity/stocks/wrb
# 6534   897320    2022   United States    /market-activity/stocks/wt
# 6540     8374           United States   /market-activity/stocks/wtm
# 6609     6532    2018  Cayman Islands   /market-activity/stocks/xyf
# 6631    57016    2015           China   /market-activity/stocks/yrd
#
# [390 rows x 11 columns]

# %%
tickers.apply_filters(exchange=['nyse','amex'], sectors=['Finance', 'Consumer Staples'])
print(len(tickers.data))
tickers.data
# Out:
# 479
#      symbol                                               name exchange  \
# 6      AACT  Ares Acquisition Corporation II Class A Ordina...     nyse
# 11     AAMC               Altisource Asset Management Corp Com     amex
# 19       AB              AllianceBernstein Holding L.P.  Units     nyse
# 25     ABEV  Ambev S.A. American Depositary Shares (Each re...     nyse
# 33      ABM           ABM Industries Incorporated Common Stock     nyse
# ...     ...                                                ...      ...
# 6534     WT                       WisdomTree Inc. Common Stock     nyse
# 6540    WTM  White Mountains Insurance Group Ltd. Common Stock     nyse
# 6609    XYF  X Financial American Depositary Shares each re...     nyse
# 6631    YRD  Yiren Digital Ltd. American Depositary Shares ...     nyse
# 6690   ZVIA                     Zevia PBC Class A Common Stock     nyse
#
#      marketCap            sector                             industry  \
# 6          0.0           Finance                         Blank Checks
# 11        6.39           Finance                          Real Estate
# 19      3869.5           Finance                  Investment Managers
# 25    33083.05  Consumer Staples  Beverages (Production/Distribution)
# 33     3374.17           Finance      Diversified Commercial Services
# ...        ...               ...                                  ...
# 6534   1639.62           Finance   Investment Bankers/Brokers/Service
# 6540   4425.48           Finance           Property-Casualty Insurers
# 6609    211.36           Finance           Finance: Consumer Services
# 6631    418.16           Finance           Finance: Consumer Services
# 6690     53.66  Consumer Staples  Beverages (Production/Distribution)
#
#       lastsale    volume ipoyear         country                           url
# 6       $10.72     63179    2023                  /market-activity/stocks/aact
# 11       $2.50       751           United States  /market-activity/stocks/aamc
# 19      $33.60    238101           United States    /market-activity/stocks/ab
# 25       $2.10  24385965    2013          Brazil  /market-activity/stocks/abev
# 33      $53.76    466259           United States   /market-activity/stocks/abm
# ...        ...       ...     ...             ...                           ...
# 6534    $10.80    897320    2022   United States    /market-activity/stocks/wt
# 6540  $1724.84      8374           United States   /market-activity/stocks/wtm
# 6609     $4.32      6532    2018  Cayman Islands   /market-activity/stocks/xyf
# 6631     $4.81     57016    2015           China   /market-activity/stocks/yrd
# 6690   $0.7422    130680    2021   United States  /market-activity/stocks/zvia
#
# [479 rows x 11 columns]

# %% [markdown]
# ## Market Capitalization Filtering

# %% [markdown]
# The script provides functionality to filter stocks based on market capitalization:

# %%
# highest market capitalization of all the stocks in the dataset
print(f'The highest market capitalization in USD Millions is {tickers.max_cap}')
# Out:
# The highest market capitalization in USD Millions is 3437594.5

# %% [markdown]
# To facilitate market cap filtering, we use a helper function that creates a logarithmic scale of 10 market cap values. This approach accounts for the skewed distribution of market caps in US stocks, where a few companies have enormous capitalizations while the majority have more moderate values.

# %%
log_ladder_cap = tk.generate_mktcap_values(tickers.max_cap)
print(log_ladder_cap)
# Out:
# [0.0, 5.3, 28.5, 151.8, 810.0, 4300, 23000, 120000, 650000, 3600000]

# %% [markdown]
# ### Combining Filters

# %% [markdown]
# We can combine multiple filters for more precise selection:

# %%
tickers.apply_filters(sectors=['Finance', 'Consumer Staples', 'Industrials'], mktcap_min=log_ladder_cap[3], mktcap_max=log_ladder_cap[7])
print(len(tickers.data))
tickers.data.sort_values('marketCap',ascending=False)
# Out:
# 1214
#      symbol                                               name exchange  \
# 3584    LMT           Lockheed Martin Corporation Common Stock     nyse
# 5340   SCHW      Charles Schwab Corporation (The) Common Stock     nyse
# 5600   SONY  Sony Group Corporation American Depositary Sha...     nyse
# 644      BA                  Boeing Company (The) Common Stock     nyse
# 1117     CB                        Chubb Limited  Common Stock     nyse
# ...     ...                                                ...      ...
# 5002    QSI       Quantum-Si Incorporated Class A Common Stock   nasdaq
# 2531   GEVO                             Gevo Inc. Common Stock   nasdaq
# 6137   UEIC            Universal Electronics Inc. Common Stock   nasdaq
# 2214   FCCO           First Community Corporation Common Stock   nasdaq
# 5816   TAYD                   Taylor Devices Inc. Common Stock   nasdaq
#
#       marketCap            sector                            industry  \
# 3584  114210.56       Industrials       Military/Government/Technical
# 5340  113840.46           Finance  Investment Bankers/Brokers/Service
# 5600  113839.04  Consumer Staples     Consumer Electronics/Appliances
# 644   110640.35       Industrials                           Aerospace
# 1117  108690.36           Finance          Property-Casualty Insurers
# ...         ...               ...                                 ...
# 5002     154.58       Industrials     Industrial Machinery/Components
# 2531     153.76       Industrials                     Major Chemicals
# 6137     153.66  Consumer Staples     Consumer Electronics/Appliances
# 2214     152.27           Finance                         Major Banks
# 5816     152.22       Industrials     Industrial Machinery/Components
#
#      lastsale    volume ipoyear        country                           url
# 3584  $476.00    967369          United States   /market-activity/stocks/lmt
# 5340   $62.27  21473989          United States  /market-activity/stocks/schw
# 5600   $93.20    662480                  Japan  /market-activity/stocks/sony
# 644   $180.23   5341672          United States    /market-activity/stocks/ba
# 1117  $267.67   2046886            Switzerland    /market-activity/stocks/cb
# ...       ...       ...     ...            ...                           ...
# 5002    $1.09    623927    2020  United States   /market-activity/stocks/qsi
# 2531  $0.6509   2136480    2011  United States  /market-activity/stocks/gevo
# 6137   $11.92     53445    1993  United States  /market-activity/stocks/ueic
# 2214   $19.96     48726          United States  /market-activity/stocks/fcco
# 5816   $49.20     16957          United States  /market-activity/stocks/tayd
#
# [1214 rows x 11 columns]

# %% [markdown]
# Let's grab only the top 25 of the selected stocks.

# %%
tickers.get_biggest_n_tickers(top_n=25)
tickers.data
# Out:
#      symbol                                               name exchange  \
# 3584    LMT           Lockheed Martin Corporation Common Stock     nyse
# 5340   SCHW      Charles Schwab Corporation (The) Common Stock     nyse
# 5600   SONY  Sony Group Corporation American Depositary Sha...     nyse
# 644      BA                  Boeing Company (The) Common Stock     nyse
# 1117     CB                        Chubb Limited  Common Stock     nyse
# 3898    MMC       Marsh & McLennan Companies Inc. Common Stock     nyse
# 6124    UBS            UBS Group AG Registered Ordinary Shares     nyse
# 1021    BUD    Anheuser-Busch Inbev SA Sponsored ADR (Belgium)     nyse
# 1710     DE                       Deere & Company Common Stock     nyse
# 5852     TD           Toronto Dominion Bank (The) Common Stock     nyse
# 2991    IBN                    ICICI Bank Limited Common Stock     nyse
# 3367    KKR                        KKR & Co. Inc. Common Stock     nyse
# 1047     BX                       Blackstone Inc. Common Stock     nyse
# 34     ABNB                   Airbnb Inc. Class A Common Stock   nasdaq
# 5527   SMFG  Sumitomo Mitsui Financial Group Inc Unsponsore...     nyse
# 3778   MDLZ   Mondelez International Inc. Class A Common Stock   nasdaq
# 3003    ICE        Intercontinental Exchange Inc. Common Stock     nyse
# 3762    MCO                   Moody's Corporation Common Stock     nyse
# 2492     GD          General Dynamics Corporation Common Stock     nyse
# 1403    CNI     Canadian National Railway Company Common Stock     nyse
# 1466     CP  Canadian Pacific Kansas City Limited Common Sh...     nyse
# 5292    SAN         Banco Santander S.A. Sponsored ADR (Spain)     nyse
# 1624    CVS                CVS Health Corporation Common Stock     nyse
# 6064     TT                             Trane Technologies plc     nyse
# 3217    ITW              Illinois Tool Works Inc. Common Stock     nyse
#
#       marketCap            sector                                   industry  \
# 3584  114210.56       Industrials              Military/Government/Technical
# 5340  113840.46           Finance         Investment Bankers/Brokers/Service
# 5600  113839.04  Consumer Staples            Consumer Electronics/Appliances
# 644   110640.35       Industrials                                  Aerospace
# 1117  108690.36           Finance                 Property-Casualty Insurers
# 3898  107128.06           Finance                         Specialty Insurers
# 6124   105841.4           Finance                                Major Banks
# 1021  105204.67  Consumer Staples        Beverages (Production/Distribution)
# 1710  104893.09       Industrials            Industrial Machinery/Components
# 5852  102941.29           Finance                           Commercial Banks
# 2991  102856.88           Finance                           Commercial Banks
# 3367  101971.33           Finance                        Investment Managers
# 1047   97484.86           Finance                        Investment Managers
# 34     94597.16           Finance            Diversified Commercial Services
# 5527    93158.9           Finance                           Commercial Banks
# 3778   89763.75  Consumer Staples                             Packaged Foods
# 3003   84752.86           Finance         Investment Bankers/Brokers/Service
# 3762   81956.36           Finance                 Finance: Consumer Services
# 2492   80462.75       Industrials                      Marine Transportation
# 1403   77974.64       Industrials                                  Railroads
# 1466   77591.98       Industrials                                  Railroads
# 5292   76437.54           Finance                           Commercial Banks
# 1624   75209.39  Consumer Staples  Retail-Drug Stores and Proprietary Stores
# 6064   74780.05       Industrials                          Auto Parts:O.E.M.
# 3217   74388.14       Industrials            Industrial Machinery/Components
#
#      lastsale    volume ipoyear        country                           url
# 3584  $476.00    967369          United States   /market-activity/stocks/lmt
# 5340   $62.27  21473989          United States  /market-activity/stocks/schw
# 5600   $93.20    662480                  Japan  /market-activity/stocks/sony
# 644   $180.23   5341672          United States    /market-activity/stocks/ba
# 1117  $267.67   2046886            Switzerland    /market-activity/stocks/cb
# 3898  $217.42   2124460          United States   /market-activity/stocks/mmc
# 6124   $30.59   1302491    2014    Switzerland   /market-activity/stocks/ubs
# 1021   $60.56   1183723                Belgium   /market-activity/stocks/bud
# 1710  $380.64   1735744          United States    /market-activity/stocks/de
# 5852   $58.09   2081013                 Canada    /market-activity/stocks/td
# 2991   $29.46   5150954                  India   /market-activity/stocks/ibn
# 3367  $114.91   4580312          United States   /market-activity/stocks/kkr
# 1047  $136.41   7322581    2007  United States    /market-activity/stocks/bx
# 34    $146.88   3591400    2020  United States  /market-activity/stocks/abnb
# 5527   $13.93   1011261                  Japan  /market-activity/stocks/smfg
# 3778   $66.92   5686389          United States  /market-activity/stocks/mdlz
# 3003  $147.76   3069070    2005  United States   /market-activity/stocks/ice
# 3762  $448.83    846948          United States   /market-activity/stocks/mco
# 2492  $293.27    876912          United States    /market-activity/stocks/gd
# 1403  $121.11    725964                 Canada   /market-activity/stocks/cni
# 1466   $83.28   1393577                 Canada    /market-activity/stocks/cp
# 5292    $4.83   1338567                  Spain   /market-activity/stocks/san
# 1624   $59.91   6423443          United States   /market-activity/stocks/cvs
# 6064  $330.37   1537580                Ireland    /market-activity/stocks/tt
# 3217  $249.29   1197370          United States   /market-activity/stocks/itw

# %% [markdown]
# ## Finalizing and Exporting Results

# %% [markdown]
# Finally, we can view the resulting ticker list and export it to a .txt file or to a .csv file. By default, the file is saved in the Downloads folder:

# %%
tickers.tickers_list
# Out:
# ['LMT',
#  'SCHW',
#  'SONY',
#  'BA',
#  'CB',
#  'MMC',
#  'UBS',
#  'BUD',
#  'DE',
#  'TD',
#  'IBN',
#  'KKR',
#  'BX',
#  'ABNB',
#  'SMFG',
#  'MDLZ',
#  'ICE',
#  'MCO',
#  'GD',
#  'CNI',
#  'CP',
#  'SAN',
#  'CVS',
#  'TT',
#  'ITW']

# %%
tickers.save_tickers()

# %%
tickers.save_tickers(csvformat=True)
